# %%
#Import Necessary Modules
import boto3
from langchain_aws import ChatBedrock
import os
from dotenv import load_dotenv
load_dotenv()

try:
   aws_access_key = os.getenv("AWS_ACCESS_KEY_ID")
   aws_secret_key = os.getenv("AWS_SECRET_ACCESS_KEY")
   region_name = "us-east-1"
   model_name = "amazon.nova-lite-v1:0"

   if not aws_access_key or not aws_secret_key:
       raise ValueError("AWS credentials are missing. Ensure AWS_ACCESS_KEY_ID and AWS_SECRET_ACCESS_KEY are set in the .env file.")

except Exception as e:
   print(f"Error loading environment variables: {e}")
   raise

#Initialize AWS Bedrock Client
try:
   bedrock_client = boto3.client(
       service_name="bedrock-runtime",
       region_name=region_name,
       aws_access_key_id=aws_access_key,
       aws_secret_access_key=aws_secret_key
   )
except Exception as e:
   print(f"Error initializing Bedrock client: {e}")
   raise

#Set Up LangChain ChatBedrock LLM
try:
   llm = ChatBedrock(
       client=bedrock_client,
       model_id=model_name,
       model_kwargs=dict(temperature=0)
   )
except Exception as e:
   print(f"Error setting up ChatBedrock LLM: {e}")
   raise


query = "Create list of 3 popular movies"
try:
   response = llm.invoke(query)
   print("LLM Response:", response)
except Exception as e:
   print(f"Error invoking the LLM: {e}")
   raise
# Out:
# Error invoking the LLM: 1 validation error for ChatBedrockConverse
#   Value error, Could not load credentials to authenticate with AWS client. Please check that credentials in the specified profile name are valid. Bedrock error:
#
# You must specify a region. [type=value_error, input_value={'model': 'amazon.nova-li...sable_streaming': False}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.9/v/value_error
# ---------------------------------------------------------------------------
# ValidationError                           Traceback (most recent call last)
# Cell In[2], line 47
#      45 query = "Create list of 3 popular movies"
#      46 try:
# ---> 47    response = llm.invoke(query)
#      48    print("LLM Response:", response)
#      49 except Exception as e:
#
# File /opt/conda/envs/myenv/lib/python3.10/site-packages/langchain_core/language_models/chat_models.py:286, in BaseChatModel.invoke(self, input, config, stop, **kwargs)
#     275 def invoke(
#     276     self,
#     277     input: LanguageModelInput,
#    (...)
#     281     **kwargs: Any,
#     282 ) -> BaseMessage:
#     283     config = ensure_config(config)
#     284     return cast(
#     285         ChatGeneration,
# --> 286         self.generate_prompt(
#     287             [self._convert_input(input)],
#     288             stop=stop,
#     289             callbacks=config.get("callbacks"),
#     290             tags=config.get("tags"),
#     291             metadata=config.get("metadata"),
#     292             run_name=config.get("run_name"),
#     293             run_id=config.pop("run_id", None),
#     294             **kwargs,
#     295         ).generations[0][0],
#     296     ).message
#
# File /opt/conda/envs/myenv/lib/python3.10/site-packages/langchain_core/language_models/chat_models.py:786, in BaseChatModel.generate_prompt(self, prompts, stop, callbacks, **kwargs)
#     778 def generate_prompt(
#     779     self,
#     780     prompts: list[PromptValue],
#    (...)
#     783     **kwargs: Any,
#     784 ) -> LLMResult:
#     785     prompt_messages = [p.to_messages() for p in prompts]
# --> 786     return self.generate(prompt_messages, stop=stop, callbacks=callbacks, **kwargs)
#
# File /opt/conda/envs/myenv/lib/python3.10/site-packages/langchain_core/language_models/chat_models.py:643, in BaseChatModel.generate(self, messages, stop, callbacks, tags, metadata, run_name, run_id, **kwargs)
#     641         if run_managers:
#     642             run_managers[i].on_llm_error(e, response=LLMResult(generations=[]))
# --> 643         raise e
#     644 flattened_outputs = [
#     645     LLMResult(generations=[res.generations], llm_output=res.llm_output)  # type: ignore[list-item]
#     646     for res in results
#     647 ]
#     648 llm_output = self._combine_llm_outputs([res.llm_output for res in results])
#
# File /opt/conda/envs/myenv/lib/python3.10/site-packages/langchain_core/language_models/chat_models.py:633, in BaseChatModel.generate(self, messages, stop, callbacks, tags, metadata, run_name, run_id, **kwargs)
#     630 for i, m in enumerate(messages):
#     631     try:
#     632         results.append(
# --> 633             self._generate_with_cache(
#     634                 m,
#     635                 stop=stop,
#     636                 run_manager=run_managers[i] if run_managers else None,
#     637                 **kwargs,
#     638             )
#     639         )
#     640     except BaseException as e:
#     641         if run_managers:
#
# File /opt/conda/envs/myenv/lib/python3.10/site-packages/langchain_core/language_models/chat_models.py:851, in BaseChatModel._generate_with_cache(self, messages, stop, run_manager, **kwargs)
#     849 else:
#     850     if inspect.signature(self._generate).parameters.get("run_manager"):
# --> 851         result = self._generate(
#     852             messages, stop=stop, run_manager=run_manager, **kwargs
#     853         )
#     854     else:
#     855         result = self._generate(messages, stop=stop, **kwargs)
#
# File /opt/conda/envs/myenv/lib/python3.10/site-packages/langchain_aws/chat_models/bedrock.py:524, in ChatBedrock._generate(self, messages, stop, run_manager, **kwargs)
#     516 def _generate(
#     517     self,
#     518     messages: List[BaseMessage],
#    (...)
#     521     **kwargs: Any,
#     522 ) -> ChatResult:
#     523     if self.beta_use_converse_api:
# --> 524         return self._as_converse._generate(
#     525             messages, stop=stop, run_manager=run_manager, **kwargs
#     526         )
#     527     completion = ""
#     528     llm_output: Dict[str, Any] = {}
#
# File /opt/conda/envs/myenv/lib/python3.10/site-packages/langchain_aws/chat_models/bedrock.py:853, in ChatBedrock._as_converse(self)
#     851 if self.temperature is not None:
#     852     kwargs["temperature"] = self.temperature
# --> 853 return ChatBedrockConverse(
#     854     model=self.model_id,
#     855     region_name=self.region_name,
#     856     credentials_profile_name=self.credentials_profile_name,
#     857     aws_access_key_id=self.aws_access_key_id,
#     858     aws_secret_access_key=self.aws_secret_access_key,
#     859     aws_session_token=self.aws_session_token,
#     860     config=self.config,
#     861     provider=self.provider or "",
#     862     base_url=self.endpoint_url,
#     863     guardrail_config=(self.guardrails if self._guardrails_enabled else None),  # type: ignore[call-arg]
#     864     **kwargs,
#     865 )
#
# File /opt/conda/envs/myenv/lib/python3.10/site-packages/langchain_core/load/serializable.py:125, in Serializable.__init__(self, *args, **kwargs)
#     123 def __init__(self, *args: Any, **kwargs: Any) -> None:
#     124     """"""
# --> 125     super().__init__(*args, **kwargs)
#
# File /opt/conda/envs/myenv/lib/python3.10/site-packages/pydantic/main.py:212, in BaseModel.__init__(self, **data)
#     210 # `__tracebackhide__` tells pytest and some other tools to omit this function from tracebacks
#     211 __tracebackhide__ = True
# --> 212 validated_self = self.__pydantic_validator__.validate_python(data, self_instance=self)
#     213 if self is not validated_self:
#     214     warnings.warn(
#     215         'A custom validator is returning a value other than `self`.\n'
#     216         "Returning anything other than `self` from a top level model validator isn't supported when validating via `__init__`.\n"
#     217         'See the `model_validator` docs (https://docs.pydantic.dev/latest/concepts/validators/#model-validators) for more details.',
#     218         category=None,
#     219     )
#
# ValidationError: 1 validation error for ChatBedrockConverse
#   Value error, Could not load credentials to authenticate with AWS client. Please check that credentials in the specified profile name are valid. Bedrock error:
#
# You must specify a region. [type=value_error, input_value={'model': 'amazon.nova-li...sable_streaming': False}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.9/v/value_error
